# %% [markdown]
# # Brewing Logistic Regression then Going Deeper
#
# While Caffe is made for deep networks it can likewise represent "shallow" models like logistic regression for classification. We'll do simple logistic regression on synthetic data that we'll generate and save to HDF5 to feed vectors to Caffe. Once that model is done, we'll add layers to improve accuracy. That's what Caffe is about: define a model, experiment, and then deploy.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import os
os.chdir('..')

import sys
sys.path.insert(0, './python')
import caffe


import os
import h5py
import shutil
import tempfile

import sklearn
import sklearn.datasets
import sklearn.linear_model

import pandas as pd

# %% [markdown]
# Synthesize a dataset of 10,000 4-vectors for binary classification with 2 informative features and 2 noise features.

# %%
X, y = sklearn.datasets.make_classification(
    n_samples=10000, n_features=4, n_redundant=0, n_informative=2, 
    n_clusters_per_class=2, hypercube=False, random_state=0
)

# Split into train and test
X, Xt, y, yt = sklearn.cross_validation.train_test_split(X, y)

# Visualize sample of the data
ind = np.random.permutation(X.shape[0])[:1000]
df = pd.DataFrame(X[ind])
_ = pd.scatter_matrix(df, figsize=(9, 9), diagonal='kde', marker='o', s=40, alpha=.4, c=y[ind])

# %% [markdown]
# Learn and evaluate scikit-learn's logistic regression with stochastic gradient descent (SGD) training. Time and check the classifier's accuracy.

# %%
# %%timeit
# Train and test the scikit-learn SGD logistic regression.
clf = sklearn.linear_model.SGDClassifier(
    loss='log', n_iter=1000, penalty='l2', alpha=1e-3, class_weight='auto')

clf.fit(X, y)
yt_pred = clf.predict(Xt)
print('Accuracy: {:.3f}'.format(sklearn.metrics.accuracy_score(yt, yt_pred)))
# Out:
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/sklearn/utils/class_weight.py:62: DeprecationWarning: The class_weight='auto' heuristic is deprecated in 0.17 in favor of a new heuristic class_weight='balanced'. 'auto' will be removed in 0.19
#   " 0.19", DeprecationWarning)
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/sklearn/utils/class_weight.py:62: DeprecationWarning: The class_weight='auto' heuristic is deprecated in 0.17 in favor of a new heuristic class_weight='balanced'. 'auto' will be removed in 0.19
#   " 0.19", DeprecationWarning)
# Accuracy: 0.758
# Accuracy: 0.758
# Accuracy: 0.758
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/sklearn/utils/class_weight.py:62: DeprecationWarning: The class_weight='auto' heuristic is deprecated in 0.17 in favor of a new heuristic class_weight='balanced'. 'auto' will be removed in 0.19
#   " 0.19", DeprecationWarning)
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/sklearn/utils/class_weight.py:62: DeprecationWarning: The class_weight='auto' heuristic is deprecated in 0.17 in favor of a new heuristic class_weight='balanced'. 'auto' will be removed in 0.19
#   " 0.19", DeprecationWarning)
# Accuracy: 0.758
# 1 loops, best of 3: 714 ms per loop

# %% [markdown]
# Save the dataset to HDF5 for loading in Caffe.

# %%
# Write out the data to HDF5 files in a temp directory.
# This file is assumed to be caffe_root/examples/hdf5_classification.ipynb
dirname = os.path.abspath('./examples/hdf5_classification/data')
if not os.path.exists(dirname):
    os.makedirs(dirname)

train_filename = os.path.join(dirname, 'train.h5')
test_filename = os.path.join(dirname, 'test.h5')

# HDF5DataLayer source should be a file containing a list of HDF5 filenames.
# To show this off, we'll list the same data file twice.
with h5py.File(train_filename, 'w') as f:
    f['data'] = X
    f['label'] = y.astype(np.float32)
with open(os.path.join(dirname, 'train.txt'), 'w') as f:
    f.write(train_filename + '\n')
    f.write(train_filename + '\n')
    
# HDF5 is pretty efficient, but can be further compressed.
comp_kwargs = {'compression': 'gzip', 'compression_opts': 1}
with h5py.File(test_filename, 'w') as f:
    f.create_dataset('data', data=Xt, **comp_kwargs)
    f.create_dataset('label', data=yt.astype(np.float32), **comp_kwargs)
with open(os.path.join(dirname, 'test.txt'), 'w') as f:
    f.write(test_filename + '\n')

# %% [markdown]
# Let's define logistic regression in Caffe through Python net specification. This is a quick and natural way to define nets that sidesteps manually editing the protobuf model.

# %%
from caffe import layers as L
from caffe import params as P

def logreg(hdf5, batch_size):
    # logistic regression: data, matrix multiplication, and 2-class softmax loss
    n = caffe.NetSpec()
    n.data, n.label = L.HDF5Data(batch_size=batch_size, source=hdf5, ntop=2)
    n.ip1 = L.InnerProduct(n.data, num_output=2, weight_filler=dict(type='xavier'))
    n.accuracy = L.Accuracy(n.ip1, n.label)
    n.loss = L.SoftmaxWithLoss(n.ip1, n.label)
    return n.to_proto()
    
with open('examples/hdf5_classification/logreg_auto_train.prototxt', 'w') as f:
    f.write(str(logreg('examples/hdf5_classification/data/train.txt', 10)))
    
with open('examples/hdf5_classification/logreg_auto_test.prototxt', 'w') as f:
    f.write(str(logreg('examples/hdf5_classification/data/test.txt', 10)))

# %% [markdown]
# Time to learn and evaluate our Caffeinated logistic regression in Python.

# %%
# %%timeit
caffe.set_mode_cpu()
solver = caffe.get_solver('examples/hdf5_classification/solver.prototxt')
solver.solve()

accuracy = 0
batch_size = solver.test_nets[0].blobs['data'].num
test_iters = int(len(Xt) / batch_size)
for i in range(test_iters):
    solver.test_nets[0].forward()
    accuracy += solver.test_nets[0].blobs['accuracy'].data
accuracy /= test_iters

print("Accuracy: {:.3f}".format(accuracy))
# Out:
# Accuracy: 0.761
# Accuracy: 0.761
# Accuracy: 0.761
# Accuracy: 0.761
# 1 loops, best of 3: 231 ms per loop

# %% [markdown]
# Do the same through the command line interface for detailed output on the model and solving.

# %%
# !./build/tools/caffe train -solver examples/hdf5_classification/solver.prototxt
# Out:
# libdc1394 error: Failed to initialize libdc1394
# I1009 23:20:54.226814  2979 caffe.cpp:178] Use CPU.
# I1009 23:20:54.366502  2979 solver.cpp:48] Initializing solver from parameters:
# train_net: "examples/hdf5_classification/logreg_auto_train.prototxt"
# test_net: "examples/hdf5_classification/logreg_auto_test.prototxt"
# test_iter: 250
# test_interval: 1000
# base_lr: 0.01
# display: 1000
# max_iter: 10000
# lr_policy: "step"
# gamma: 0.1
# momentum: 0.9
# weight_decay: 0.0005
# stepsize: 5000
# snapshot: 10000
# snapshot_prefix: "examples/hdf5_classification/data/train"
# solver_mode: CPU
# I1009 23:20:54.366778  2979 solver.cpp:81] Creating training net from train_net file: examples/hdf5_classification/logreg_auto_train.prototxt
# I1009 23:20:54.367100  2979 net.cpp:49] Initializing net from parameters:
# state {
#   phase: TRAIN
# }
# layer {
#   name: "data"
#   type: "HDF5Data"
#   top: "data"
#   top: "label"
#   hdf5_data_param {
#     source: "examples/hdf5_classification/data/train.txt"
#     batch_size: 10
#   }
# }
# layer {
#   name: "ip1"
#   type: "InnerProduct"
#   bottom: "data"
#   top: "ip1"
#   inner_product_param {
#     num_output: 2
#     weight_filler {
#       type: "xavier"
#     }
#   }
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "ip1"
#   bottom: "label"
#   top: "accuracy"
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "ip1"
#   bottom: "label"
#   top: "loss"
# }
# I1009 23:20:54.367272  2979 layer_factory.hpp:77] Creating layer data
# I1009 23:20:54.367301  2979 net.cpp:106] Creating Layer data
# I1009 23:20:54.367314  2979 net.cpp:411] data -> data
# I1009 23:20:54.367348  2979 net.cpp:411] data -> label
# I1009 23:20:54.367393  2979 hdf5_data_layer.cpp:79] Loading list of HDF5 filenames from: examples/hdf5_classification/data/train.txt
# I1009 23:20:54.367452  2979 hdf5_data_layer.cpp:93] Number of HDF5 files: 2
# I1009 23:20:54.368559  2979 hdf5.cpp:32] Datatype class: H5T_FLOAT
# I1009 23:20:54.369062  2979 net.cpp:150] Setting up data
# I1009 23:20:54.369082  2979 net.cpp:157] Top shape: 10 4 (40)
# I1009 23:20:54.369091  2979 net.cpp:157] Top shape: 10 (10)
# I1009 23:20:54.369096  2979 net.cpp:165] Memory required for data: 200
# I1009 23:20:54.369105  2979 layer_factory.hpp:77] Creating layer label_data_1_split
# I1009 23:20:54.369118  2979 net.cpp:106] Creating Layer label_data_1_split
# I1009 23:20:54.369127  2979 net.cpp:454] label_data_1_split <- label
# I1009 23:20:54.369141  2979 net.cpp:411] label_data_1_split -> label_data_1_split_0
# I1009 23:20:54.369153  2979 net.cpp:411] label_data_1_split -> label_data_1_split_1
# I1009 23:20:54.369166  2979 net.cpp:150] Setting up label_data_1_split
# I1009 23:20:54.369177  2979 net.cpp:157] Top shape: 10 (10)
# I1009 23:20:54.369184  2979 net.cpp:157] Top shape: 10 (10)
# I1009 23:20:54.369189  2979 net.cpp:165] Memory required for data: 280
# I1009 23:20:54.369195  2979 layer_factory.hpp:77] Creating layer ip1
# I1009 23:20:54.369206  2979 net.cpp:106] Creating Layer ip1
# I1009 23:20:54.369213  2979 net.cpp:454] ip1 <- data
# I1009 23:20:54.369221  2979 net.cpp:411] ip1 -> ip1
# I1009 23:20:54.369616  2979 net.cpp:150] Setting up ip1
# I1009 23:20:54.369628  2979 net.cpp:157] Top shape: 10 2 (20)
# I1009 23:20:54.369634  2979 net.cpp:165] Memory required for data: 360
# I1009 23:20:54.369654  2979 layer_factory.hpp:77] Creating layer ip1_ip1_0_split
# I1009 23:20:54.369663  2979 net.cpp:106] Creating Layer ip1_ip1_0_split
# I1009 23:20:54.369669  2979 net.cpp:454] ip1_ip1_0_split <- ip1
# I1009 23:20:54.369676  2979 net.cpp:411] ip1_ip1_0_split -> ip1_ip1_0_split_0
# I1009 23:20:54.369686  2979 net.cpp:411] ip1_ip1_0_split -> ip1_ip1_0_split_1
# I1009 23:20:54.369696  2979 net.cpp:150] Setting up ip1_ip1_0_split
# I1009 23:20:54.369704  2979 net.cpp:157] Top shape: 10 2 (20)
# I1009 23:20:54.369709  2979 net.cpp:157] Top shape: 10 2 (20)
# I1009 23:20:54.369715  2979 net.cpp:165] Memory required for data: 520
# I1009 23:20:54.369720  2979 layer_factory.hpp:77] Creating layer accuracy
# I1009 23:20:54.369731  2979 net.cpp:106] Creating Layer accuracy
# I1009 23:20:54.369737  2979 net.cpp:454] accuracy <- ip1_ip1_0_split_0
# I1009 23:20:54.369743  2979 net.cpp:454] accuracy <- label_data_1_split_0
# I1009 23:20:54.369751  2979 net.cpp:411] accuracy -> accuracy
# I1009 23:20:54.369763  2979 net.cpp:150] Setting up accuracy
# I1009 23:20:54.369787  2979 net.cpp:157] Top shape: (1)
# I1009 23:20:54.369793  2979 net.cpp:165] Memory required for data: 524
# I1009 23:20:54.369799  2979 layer_factory.hpp:77] Creating layer loss
# I1009 23:20:54.369809  2979 net.cpp:106] Creating Layer loss
# I1009 23:20:54.369817  2979 net.cpp:454] loss <- ip1_ip1_0_split_1
# I1009 23:20:54.369822  2979 net.cpp:454] loss <- label_data_1_split_1
# I1009 23:20:54.369829  2979 net.cpp:411] loss -> loss
# I1009 23:20:54.369848  2979 layer_factory.hpp:77] Creating layer loss
# I1009 23:20:54.521755  2979 net.cpp:150] Setting up loss
# I1009 23:20:54.521833  2979 net.cpp:157] Top shape: (1)
# I1009 23:20:54.521852  2979 net.cpp:160]     with loss weight 1
# I1009 23:20:54.521898  2979 net.cpp:165] Memory required for data: 528
# I1009 23:20:54.521917  2979 net.cpp:226] loss needs backward computation.
# I1009 23:20:54.521935  2979 net.cpp:228] accuracy does not need backward computation.
# I1009 23:20:54.521952  2979 net.cpp:226] ip1_ip1_0_split needs backward computation.
# I1009 23:20:54.521968  2979 net.cpp:226] ip1 needs backward computation.
# I1009 23:20:54.521984  2979 net.cpp:228] label_data_1_split does not need backward computation.
# I1009 23:20:54.522020  2979 net.cpp:228] data does not need backward computation.
# I1009 23:20:54.522035  2979 net.cpp:270] This network produces output accuracy
# I1009 23:20:54.522053  2979 net.cpp:270] This network produces output loss
# I1009 23:20:54.522078  2979 net.cpp:283] Network initialization done.
# I1009 23:20:54.522330  2979 solver.cpp:181] Creating test net (#0) specified by test_net file: examples/hdf5_classification/logreg_auto_test.prototxt
# I1009 23:20:54.522424  2979 net.cpp:49] Initializing net from parameters:
# state {
#   phase: TEST
# }
# layer {
#   name: "data"
#   type: "HDF5Data"
#   top: "data"
#   top: "label"
#   hdf5_data_param {
#     source: "examples/hdf5_classification/data/test.txt"
#     batch_size: 10
#   }
# }
# layer {
#   name: "ip1"
#   type: "InnerProduct"
#   bottom: "data"
#   top: "ip1"
#   inner_product_param {
#     num_output: 2
#     weight_filler {
#       type: "xavier"
#     }
#   }
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "ip1"
#   bottom: "label"
#   top: "accuracy"
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "ip1"
#   bottom: "label"
#   top: "loss"
# }
# I1009 23:20:54.522696  2979 layer_factory.hpp:77] Creating layer data
# I1009 23:20:54.522722  2979 net.cpp:106] Creating Layer data
# I1009 23:20:54.522738  2979 net.cpp:411] data -> data
# I1009 23:20:54.522761  2979 net.cpp:411] data -> label
# I1009 23:20:54.522783  2979 hdf5_data_layer.cpp:79] Loading list of HDF5 filenames from: examples/hdf5_classification/data/test.txt
# I1009 23:20:54.522827  2979 hdf5_data_layer.cpp:93] Number of HDF5 files: 1
# I1009 23:20:54.524746  2979 net.cpp:150] Setting up data
# I1009 23:20:54.524786  2979 net.cpp:157] Top shape: 10 4 (40)
# I1009 23:20:54.524806  2979 net.cpp:157] Top shape: 10 (10)
# I1009 23:20:54.524821  2979 net.cpp:165] Memory required for data: 200
# I1009 23:20:54.524837  2979 layer_factory.hpp:77] Creating layer label_data_1_split
# I1009 23:20:54.524858  2979 net.cpp:106] Creating Layer label_data_1_split
# I1009 23:20:54.524873  2979 net.cpp:454] label_data_1_split <- label
# I1009 23:20:54.524893  2979 net.cpp:411] label_data_1_split -> label_data_1_split_0
# I1009 23:20:54.524915  2979 net.cpp:411] label_data_1_split -> label_data_1_split_1
# I1009 23:20:54.524945  2979 net.cpp:150] Setting up label_data_1_split
# I1009 23:20:54.524963  2979 net.cpp:157] Top shape: 10 (10)
# I1009 23:20:54.524981  2979 net.cpp:157] Top shape: 10 (10)
# I1009 23:20:54.524994  2979 net.cpp:165] Memory required for data: 280
# I1009 23:20:54.525008  2979 layer_factory.hpp:77] Creating layer ip1
# I1009 23:20:54.525032  2979 net.cpp:106] Creating Layer ip1
# I1009 23:20:54.525049  2979 net.cpp:454] ip1 <- data
# I1009 23:20:54.525068  2979 net.cpp:411] ip1 -> ip1
# I1009 23:20:54.525105  2979 net.cpp:150] Setting up ip1
# I1009 23:20:54.525125  2979 net.cpp:157] Top shape: 10 2 (20)
# I1009 23:20:54.525141  2979 net.cpp:165] Memory required for data: 360
# I1009 23:20:54.525190  2979 layer_factory.hpp:77] Creating layer ip1_ip1_0_split
# I1009 23:20:54.525209  2979 net.cpp:106] Creating Layer ip1_ip1_0_split
# I1009 23:20:54.525225  2979 net.cpp:454] ip1_ip1_0_split <- ip1
# I1009 23:20:54.525243  2979 net.cpp:411] ip1_ip1_0_split -> ip1_ip1_0_split_0
# I1009 23:20:54.525262  2979 net.cpp:411] ip1_ip1_0_split -> ip1_ip1_0_split_1
# I1009 23:20:54.525285  2979 net.cpp:150] Setting up ip1_ip1_0_split
# I1009 23:20:54.525301  2979 net.cpp:157] Top shape: 10 2 (20)
# I1009 23:20:54.525318  2979 net.cpp:157] Top shape: 10 2 (20)
# I1009 23:20:54.525333  2979 net.cpp:165] Memory required for data: 520
# I1009 23:20:54.525348  2979 layer_factory.hpp:77] Creating layer accuracy
# I1009 23:20:54.525367  2979 net.cpp:106] Creating Layer accuracy
# I1009 23:20:54.525382  2979 net.cpp:454] accuracy <- ip1_ip1_0_split_0
# I1009 23:20:54.525398  2979 net.cpp:454] accuracy <- label_data_1_split_0
# I1009 23:20:54.525415  2979 net.cpp:411] accuracy -> accuracy
# I1009 23:20:54.525436  2979 net.cpp:150] Setting up accuracy
# I1009 23:20:54.525454  2979 net.cpp:157] Top shape: (1)
# I1009 23:20:54.525470  2979 net.cpp:165] Memory required for data: 524
# I1009 23:20:54.525485  2979 layer_factory.hpp:77] Creating layer loss
# I1009 23:20:54.525502  2979 net.cpp:106] Creating Layer loss
# I1009 23:20:54.525517  2979 net.cpp:454] loss <- ip1_ip1_0_split_1
# I1009 23:20:54.525534  2979 net.cpp:454] loss <- label_data_1_split_1
# I1009 23:20:54.525552  2979 net.cpp:411] loss -> loss
# I1009 23:20:54.525576  2979 layer_factory.hpp:77] Creating layer loss
# I1009 23:20:54.525995  2979 net.cpp:150] Setting up loss
# I1009 23:20:54.526023  2979 net.cpp:157] Top shape: (1)
# I1009 23:20:54.526038  2979 net.cpp:160]     with loss weight 1
# I1009 23:20:54.526058  2979 net.cpp:165] Memory required for data: 528
# I1009 23:20:54.526077  2979 net.cpp:226] loss needs backward computation.
# I1009 23:20:54.526093  2979 net.cpp:228] accuracy does not need backward computation.
# I1009 23:20:54.526109  2979 net.cpp:226] ip1_ip1_0_split needs backward computation.
# I1009 23:20:54.526124  2979 net.cpp:226] ip1 needs backward computation.
# I1009 23:20:54.526139  2979 net.cpp:228] label_data_1_split does not need backward computation.
# I1009 23:20:54.526155  2979 net.cpp:228] data does not need backward computation.
# I1009 23:20:54.526170  2979 net.cpp:270] This network produces output accuracy
# I1009 23:20:54.526185  2979 net.cpp:270] This network produces output loss
# I1009 23:20:54.526206  2979 net.cpp:283] Network initialization done.
# I1009 23:20:54.526250  2979 solver.cpp:60] Solver scaffolding done.
# I1009 23:20:54.526289  2979 caffe.cpp:213] Starting Optimization
# I1009 23:20:54.526306  2979 solver.cpp:280] Solving
# I1009 23:20:54.526320  2979 solver.cpp:281] Learning Rate Policy: step
# I1009 23:20:54.526341  2979 solver.cpp:338] Iteration 0, Testing net (#0)
# I1009 23:20:54.531023  2979 solver.cpp:406]     Test net output #0: accuracy = 0.3816
# I1009 23:20:54.531069  2979 solver.cpp:406]     Test net output #1: loss = 1.26285 (* 1 = 1.26285 loss)
# I1009 23:20:54.531157  2979 solver.cpp:229] Iteration 0, loss = 0.801346
# I1009 23:20:54.531183  2979 solver.cpp:245]     Train net output #0: accuracy = 0.5
# I1009 23:20:54.531205  2979 solver.cpp:245]     Train net output #1: loss = 0.801346 (* 1 = 0.801346 loss)
# I1009 23:20:54.531239  2979 sgd_solver.cpp:106] Iteration 0, lr = 0.01
# I1009 23:20:54.553874  2979 solver.cpp:338] Iteration 1000, Testing net (#0)
# I1009 23:20:54.558400  2979 solver.cpp:406]     Test net output #0: accuracy = 0.7632
# I1009 23:20:54.558449  2979 solver.cpp:406]     Test net output #1: loss = 0.599616 (* 1 = 0.599616 loss)
# I1009 23:20:54.558496  2979 solver.cpp:229] Iteration 1000, loss = 0.539306
# I1009 23:20:54.558519  2979 solver.cpp:245]     Train net output #0: accuracy = 0.6
# I1009 23:20:54.558542  2979 solver.cpp:245]     Train net output #1: loss = 0.539306 (* 1 = 0.539306 loss)
# I1009 23:20:54.558562  2979 sgd_solver.cpp:106] Iteration 1000, lr = 0.01
# I1009 23:20:54.581169  2979 solver.cpp:338] Iteration 2000, Testing net (#0)
# I1009 23:20:54.585674  2979 solver.cpp:406]     Test net output #0: accuracy = 0.7576
# I1009 23:20:54.585743  2979 solver.cpp:406]     Test net output #1: loss = 0.596567 (* 1 = 0.596567 loss)
# I1009 23:20:54.585793  2979 solver.cpp:229] Iteration 2000, loss = 0.698858
# I1009 23:20:54.585814  2979 solver.cpp:245]     Train net output #0: accuracy = 0.7
# I1009 23:20:54.585839  2979 solver.cpp:245]     Train net output #1: loss = 0.698858 (* 1 = 0.698858 loss)
# I1009 23:20:54.585857  2979 sgd_solver.cpp:106] Iteration 2000, lr = 0.01
# I1009 23:20:54.608399  2979 solver.cpp:338] Iteration 3000, Testing net (#0)
# I1009 23:20:54.612906  2979 solver.cpp:406]     Test net output #0: accuracy = 0.6808
# I1009 23:20:54.612953  2979 solver.cpp:406]     Test net output #1: loss = 0.608432 (* 1 = 0.608432 loss)
# I1009 23:20:54.613647  2979 solver.cpp:229] Iteration 3000, loss = 0.539734
# I1009 23:20:54.613687  2979 solver.cpp:245]     Train net output #0: accuracy = 0.7
# I1009 23:20:54.613713  2979 solver.cpp:245]     Train net output #1: loss = 0.539734 (* 1 = 0.539734 loss)
# I1009 23:20:54.613731  2979 sgd_solver.cpp:106] Iteration 3000, lr = 0.01
# I1009 23:20:54.636263  2979 solver.cpp:338] Iteration 4000, Testing net (#0)
# I1009 23:20:54.640777  2979 solver.cpp:406]     Test net output #0: accuracy = 0.7632
# I1009 23:20:54.640825  2979 solver.cpp:406]     Test net output #1: loss = 0.599616 (* 1 = 0.599616 loss)
# I1009 23:20:54.640873  2979 solver.cpp:229] Iteration 4000, loss = 0.539306
# I1009 23:20:54.640895  2979 solver.cpp:245]     Train net output #0: accuracy = 0.6
# I1009 23:20:54.640919  2979 solver.cpp:245]     Train net output #1: loss = 0.539306 (* 1 = 0.539306 loss)
# I1009 23:20:54.640938  2979 sgd_solver.cpp:106] Iteration 4000, lr = 0.01
# I1009 23:20:54.663528  2979 solver.cpp:338] Iteration 5000, Testing net (#0)
# I1009 23:20:54.668043  2979 solver.cpp:406]     Test net output #0: accuracy = 0.7576
# I1009 23:20:54.668092  2979 solver.cpp:406]     Test net output #1: loss = 0.596567 (* 1 = 0.596567 loss)
# I1009 23:20:54.668138  2979 solver.cpp:229] Iteration 5000, loss = 0.698858
# I1009 23:20:54.668161  2979 solver.cpp:245]     Train net output #0: accuracy = 0.7
# I1009 23:20:54.668185  2979 solver.cpp:245]     Train net output #1: loss = 0.698858 (* 1 = 0.698858 loss)
# I1009 23:20:54.668203  2979 sgd_solver.cpp:106] Iteration 5000, lr = 0.001
# I1009 23:20:54.690687  2979 solver.cpp:338] Iteration 6000, Testing net (#0)
# I1009 23:20:54.695171  2979 solver.cpp:406]     Test net output #0: accuracy = 0.7452
# I1009 23:20:54.695219  2979 solver.cpp:406]     Test net output #1: loss = 0.596585 (* 1 = 0.596585 loss)
# I1009 23:20:54.695888  2979 solver.cpp:229] Iteration 6000, loss = 0.519406
# I1009 23:20:54.695927  2979 solver.cpp:245]     Train net output #0: accuracy = 0.7
# I1009 23:20:54.695955  2979 solver.cpp:245]     Train net output #1: loss = 0.519406 (* 1 = 0.519406 loss)
# I1009 23:20:54.695973  2979 sgd_solver.cpp:106] Iteration 6000, lr = 0.001
# I1009 23:20:54.718410  2979 solver.cpp:338] Iteration 7000, Testing net (#0)
# I1009 23:20:54.722896  2979 solver.cpp:406]     Test net output #0: accuracy = 0.7596
# I1009 23:20:54.722944  2979 solver.cpp:406]     Test net output #1: loss = 0.595754 (* 1 = 0.595754 loss)
# I1009 23:20:54.722990  2979 solver.cpp:229] Iteration 7000, loss = 0.563899
# I1009 23:20:54.723012  2979 solver.cpp:245]     Train net output #0: accuracy = 0.7
# I1009 23:20:54.723037  2979 solver.cpp:245]     Train net output #1: loss = 0.563899 (* 1 = 0.563899 loss)
# I1009 23:20:54.723054  2979 sgd_solver.cpp:106] Iteration 7000, lr = 0.001
# I1009 23:20:54.745513  2979 solver.cpp:338] Iteration 8000, Testing net (#0)
# I1009 23:20:54.750038  2979 solver.cpp:406]     Test net output #0: accuracy = 0.7608
# I1009 23:20:54.750087  2979 solver.cpp:406]     Test net output #1: loss = 0.595913 (* 1 = 0.595913 loss)
# I1009 23:20:54.750135  2979 solver.cpp:229] Iteration 8000, loss = 0.696257
# I1009 23:20:54.750159  2979 solver.cpp:245]     Train net output #0: accuracy = 0.7
# I1009 23:20:54.750182  2979 solver.cpp:245]     Train net output #1: loss = 0.696257 (* 1 = 0.696257 loss)
# I1009 23:20:54.750222  2979 sgd_solver.cpp:106] Iteration 8000, lr = 0.001
# I1009 23:20:54.772754  2979 solver.cpp:338] Iteration 9000, Testing net (#0)
# I1009 23:20:54.777269  2979 solver.cpp:406]     Test net output #0: accuracy = 0.7504
# I1009 23:20:54.777318  2979 solver.cpp:406]     Test net output #1: loss = 0.596379 (* 1 = 0.596379 loss)
# I1009 23:20:54.778023  2979 solver.cpp:229] Iteration 9000, loss = 0.514317
# I1009 23:20:54.778062  2979 solver.cpp:245]     Train net output #0: accuracy = 0.8
# I1009 23:20:54.778090  2979 solver.cpp:245]     Train net output #1: loss = 0.514317 (* 1 = 0.514317 loss)
# I1009 23:20:54.778108  2979 sgd_solver.cpp:106] Iteration 9000, lr = 0.001
# I1009 23:20:54.800623  2979 solver.cpp:456] Snapshotting to binary proto file examples/hdf5_classification/data/train_iter_10000.caffemodel
# I1009 23:20:54.800907  2979 sgd_solver.cpp:273] Snapshotting solver state to binary proto file examples/hdf5_classification/data/train_iter_10000.solverstate
# I1009 23:20:54.801039  2979 solver.cpp:318] Iteration 10000, loss = 0.562239
# I1009 23:20:54.801070  2979 solver.cpp:338] Iteration 10000, Testing net (#0)
# I1009 23:20:54.805542  2979 solver.cpp:406]     Test net output #0: accuracy = 0.7612
# I1009 23:20:54.805585  2979 solver.cpp:406]     Test net output #1: loss = 0.595727 (* 1 = 0.595727 loss)
# I1009 23:20:54.805604  2979 solver.cpp:323] Optimization Done.
# I1009 23:20:54.805619  2979 caffe.cpp:216] Optimization Done.

# %% [markdown]
# If you look at output or the `logreg_auto_train.prototxt`, you'll see that the model is simple logistic regression.
# We can make it a little more advanced by introducing a non-linearity between weights that take the input and weights that give the output -- now we have a two-layer network.
# That network is given in `nonlinear_auto_train.prototxt`, and that's the only change made in `nonlinear_solver.prototxt` which we will now use.
#
# The final accuracy of the new network should be higher than logistic regression!

# %%
from caffe import layers as L
from caffe import params as P

def nonlinear_net(hdf5, batch_size):
    # one small nonlinearity, one leap for model kind
    n = caffe.NetSpec()
    n.data, n.label = L.HDF5Data(batch_size=batch_size, source=hdf5, ntop=2)
    # define a hidden layer of dimension 40
    n.ip1 = L.InnerProduct(n.data, num_output=40, weight_filler=dict(type='xavier'))
    # transform the output through the ReLU (rectified linear) non-linearity
    n.relu1 = L.ReLU(n.ip1, in_place=True)
    # score the (now non-linear) features
    n.ip2 = L.InnerProduct(n.ip1, num_output=2, weight_filler=dict(type='xavier'))
    # same accuracy and loss as before
    n.accuracy = L.Accuracy(n.ip2, n.label)
    n.loss = L.SoftmaxWithLoss(n.ip2, n.label)
    return n.to_proto()
    
with open('examples/hdf5_classification/nonlinear_auto_train.prototxt', 'w') as f:
    f.write(str(nonlinear_net('examples/hdf5_classification/data/train.txt', 10)))
    
with open('examples/hdf5_classification/nonlinear_auto_test.prototxt', 'w') as f:
    f.write(str(nonlinear_net('examples/hdf5_classification/data/test.txt', 10)))

# %%
# %%timeit
caffe.set_mode_cpu()
solver = caffe.get_solver('examples/hdf5_classification/nonlinear_solver.prototxt')
solver.solve()

accuracy = 0
batch_size = solver.test_nets[0].blobs['data'].num
test_iters = int(len(Xt) / batch_size)
for i in range(test_iters):
    solver.test_nets[0].forward()
    accuracy += solver.test_nets[0].blobs['accuracy'].data
accuracy /= test_iters

print("Accuracy: {:.3f}".format(accuracy))
# Out:
# Accuracy: 0.829
# Accuracy: 0.826
# Accuracy: 0.826
# Accuracy: 0.828
# 1 loops, best of 3: 352 ms per loop

# %% [markdown]
# Do the same through the command line interface for detailed output on the model and solving.

# %%
# !./build/tools/caffe train -solver examples/hdf5_classification/nonlinear_solver.prototxt
# Out:
# libdc1394 error: Failed to initialize libdc1394
# I1009 23:20:56.621011  2983 caffe.cpp:178] Use CPU.
# I1009 23:20:56.755223  2983 solver.cpp:48] Initializing solver from parameters:
# train_net: "examples/hdf5_classification/nonlinear_auto_train.prototxt"
# test_net: "examples/hdf5_classification/nonlinear_auto_test.prototxt"
# test_iter: 250
# test_interval: 1000
# base_lr: 0.01
# display: 1000
# max_iter: 10000
# lr_policy: "step"
# gamma: 0.1
# momentum: 0.9
# weight_decay: 0.0005
# stepsize: 5000
# snapshot: 10000
# snapshot_prefix: "examples/hdf5_classification/data/train"
# solver_mode: CPU
# I1009 23:20:56.755465  2983 solver.cpp:81] Creating training net from train_net file: examples/hdf5_classification/nonlinear_auto_train.prototxt
# I1009 23:20:56.755738  2983 net.cpp:49] Initializing net from parameters:
# state {
#   phase: TRAIN
# }
# layer {
#   name: "data"
#   type: "HDF5Data"
#   top: "data"
#   top: "label"
#   hdf5_data_param {
#     source: "examples/hdf5_classification/data/train.txt"
#     batch_size: 10
#   }
# }
# layer {
#   name: "ip1"
#   type: "InnerProduct"
#   bottom: "data"
#   top: "ip1"
#   inner_product_param {
#     num_output: 40
#     weight_filler {
#       type: "xavier"
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "ip1"
#   top: "ip1"
# }
# layer {
#   name: "ip2"
#   type: "InnerProduct"
#   bottom: "ip1"
#   top: "ip2"
#   inner_product_param {
#     num_output: 2
#     weight_filler {
#       type: "xavier"
#     }
#   }
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "ip2"
#   bottom: "label"
#   top: "accuracy"
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "ip2"
#   bottom: "label"
#   top: "loss"
# }
# I1009 23:20:56.756031  2983 layer_factory.hpp:77] Creating layer data
# I1009 23:20:56.756064  2983 net.cpp:106] Creating Layer data
# I1009 23:20:56.756083  2983 net.cpp:411] data -> data
# I1009 23:20:56.756124  2983 net.cpp:411] data -> label
# I1009 23:20:56.756148  2983 hdf5_data_layer.cpp:79] Loading list of HDF5 filenames from: examples/hdf5_classification/data/train.txt
# I1009 23:20:56.756189  2983 hdf5_data_layer.cpp:93] Number of HDF5 files: 2
# I1009 23:20:56.757272  2983 hdf5.cpp:32] Datatype class: H5T_FLOAT
# I1009 23:20:56.757804  2983 net.cpp:150] Setting up data
# I1009 23:20:56.757840  2983 net.cpp:157] Top shape: 10 4 (40)
# I1009 23:20:56.757855  2983 net.cpp:157] Top shape: 10 (10)
# I1009 23:20:56.757866  2983 net.cpp:165] Memory required for data: 200
# I1009 23:20:56.757879  2983 layer_factory.hpp:77] Creating layer label_data_1_split
# I1009 23:20:56.757896  2983 net.cpp:106] Creating Layer label_data_1_split
# I1009 23:20:56.757911  2983 net.cpp:454] label_data_1_split <- label
# I1009 23:20:56.757930  2983 net.cpp:411] label_data_1_split -> label_data_1_split_0
# I1009 23:20:56.757946  2983 net.cpp:411] label_data_1_split -> label_data_1_split_1
# I1009 23:20:56.757963  2983 net.cpp:150] Setting up label_data_1_split
# I1009 23:20:56.757977  2983 net.cpp:157] Top shape: 10 (10)
# I1009 23:20:56.758008  2983 net.cpp:157] Top shape: 10 (10)
# I1009 23:20:56.758026  2983 net.cpp:165] Memory required for data: 280
# I1009 23:20:56.758043  2983 layer_factory.hpp:77] Creating layer ip1
# I1009 23:20:56.758060  2983 net.cpp:106] Creating Layer ip1
# I1009 23:20:56.758071  2983 net.cpp:454] ip1 <- data
# I1009 23:20:56.758085  2983 net.cpp:411] ip1 -> ip1
# I1009 23:20:56.758486  2983 net.cpp:150] Setting up ip1
# I1009 23:20:56.758513  2983 net.cpp:157] Top shape: 10 40 (400)
# I1009 23:20:56.758524  2983 net.cpp:165] Memory required for data: 1880
# I1009 23:20:56.758553  2983 layer_factory.hpp:77] Creating layer relu1
# I1009 23:20:56.758572  2983 net.cpp:106] Creating Layer relu1
# I1009 23:20:56.758584  2983 net.cpp:454] relu1 <- ip1
# I1009 23:20:56.758595  2983 net.cpp:397] relu1 -> ip1 (in-place)
# I1009 23:20:56.874872  2983 net.cpp:150] Setting up relu1
# I1009 23:20:56.874933  2983 net.cpp:157] Top shape: 10 40 (400)
# I1009 23:20:56.874953  2983 net.cpp:165] Memory required for data: 3480
# I1009 23:20:56.874968  2983 layer_factory.hpp:77] Creating layer ip2
# I1009 23:20:56.874994  2983 net.cpp:106] Creating Layer ip2
# I1009 23:20:56.875007  2983 net.cpp:454] ip2 <- ip1
# I1009 23:20:56.875023  2983 net.cpp:411] ip2 -> ip2
# I1009 23:20:56.875061  2983 net.cpp:150] Setting up ip2
# I1009 23:20:56.875075  2983 net.cpp:157] Top shape: 10 2 (20)
# I1009 23:20:56.875110  2983 net.cpp:165] Memory required for data: 3560
# I1009 23:20:56.875131  2983 layer_factory.hpp:77] Creating layer ip2_ip2_0_split
# I1009 23:20:56.875147  2983 net.cpp:106] Creating Layer ip2_ip2_0_split
# I1009 23:20:56.875159  2983 net.cpp:454] ip2_ip2_0_split <- ip2
# I1009 23:20:56.875171  2983 net.cpp:411] ip2_ip2_0_split -> ip2_ip2_0_split_0
# I1009 23:20:56.875185  2983 net.cpp:411] ip2_ip2_0_split -> ip2_ip2_0_split_1
# I1009 23:20:56.875201  2983 net.cpp:150] Setting up ip2_ip2_0_split
# I1009 23:20:56.875214  2983 net.cpp:157] Top shape: 10 2 (20)
# I1009 23:20:56.875226  2983 net.cpp:157] Top shape: 10 2 (20)
# I1009 23:20:56.875236  2983 net.cpp:165] Memory required for data: 3720
# I1009 23:20:56.875248  2983 layer_factory.hpp:77] Creating layer accuracy
# I1009 23:20:56.875264  2983 net.cpp:106] Creating Layer accuracy
# I1009 23:20:56.875277  2983 net.cpp:454] accuracy <- ip2_ip2_0_split_0
# I1009 23:20:56.875288  2983 net.cpp:454] accuracy <- label_data_1_split_0
# I1009 23:20:56.875299  2983 net.cpp:411] accuracy -> accuracy
# I1009 23:20:56.875319  2983 net.cpp:150] Setting up accuracy
# I1009 23:20:56.875332  2983 net.cpp:157] Top shape: (1)
# I1009 23:20:56.875342  2983 net.cpp:165] Memory required for data: 3724
# I1009 23:20:56.875354  2983 layer_factory.hpp:77] Creating layer loss
# I1009 23:20:56.875368  2983 net.cpp:106] Creating Layer loss
# I1009 23:20:56.875380  2983 net.cpp:454] loss <- ip2_ip2_0_split_1
# I1009 23:20:56.875391  2983 net.cpp:454] loss <- label_data_1_split_1
# I1009 23:20:56.875402  2983 net.cpp:411] loss -> loss
# I1009 23:20:56.875427  2983 layer_factory.hpp:77] Creating layer loss
# I1009 23:20:56.875690  2983 net.cpp:150] Setting up loss
# I1009 23:20:56.875712  2983 net.cpp:157] Top shape: (1)
# I1009 23:20:56.875722  2983 net.cpp:160]     with loss weight 1
# I1009 23:20:56.875757  2983 net.cpp:165] Memory required for data: 3728
# I1009 23:20:56.875769  2983 net.cpp:226] loss needs backward computation.
# I1009 23:20:56.875780  2983 net.cpp:228] accuracy does not need backward computation.
# I1009 23:20:56.875790  2983 net.cpp:226] ip2_ip2_0_split needs backward computation.
# I1009 23:20:56.875802  2983 net.cpp:226] ip2 needs backward computation.
# I1009 23:20:56.875811  2983 net.cpp:226] relu1 needs backward computation.
# I1009 23:20:56.875821  2983 net.cpp:226] ip1 needs backward computation.
# I1009 23:20:56.875833  2983 net.cpp:228] label_data_1_split does not need backward computation.
# I1009 23:20:56.875844  2983 net.cpp:228] data does not need backward computation.
# I1009 23:20:56.875852  2983 net.cpp:270] This network produces output accuracy
# I1009 23:20:56.875864  2983 net.cpp:270] This network produces output loss
# I1009 23:20:56.875880  2983 net.cpp:283] Network initialization done.
# I1009 23:20:56.876087  2983 solver.cpp:181] Creating test net (#0) specified by test_net file: examples/hdf5_classification/nonlinear_auto_test.prototxt
# I1009 23:20:56.876163  2983 net.cpp:49] Initializing net from parameters:
# state {
#   phase: TEST
# }
# layer {
#   name: "data"
#   type: "HDF5Data"
#   top: "data"
#   top: "label"
#   hdf5_data_param {
#     source: "examples/hdf5_classification/data/test.txt"
#     batch_size: 10
#   }
# }
# layer {
#   name: "ip1"
#   type: "InnerProduct"
#   bottom: "data"
#   top: "ip1"
#   inner_product_param {
#     num_output: 40
#     weight_filler {
#       type: "xavier"
#     }
#   }
# }
# layer {
#   name: "relu1"
#   type: "ReLU"
#   bottom: "ip1"
#   top: "ip1"
# }
# layer {
#   name: "ip2"
#   type: "InnerProduct"
#   bottom: "ip1"
#   top: "ip2"
#   inner_product_param {
#     num_output: 2
#     weight_filler {
#       type: "xavier"
#     }
#   }
# }
# layer {
#   name: "accuracy"
#   type: "Accuracy"
#   bottom: "ip2"
#   bottom: "label"
#   top: "accuracy"
# }
# layer {
#   name: "loss"
#   type: "SoftmaxWithLoss"
#   bottom: "ip2"
#   bottom: "label"
#   top: "loss"
# }
# I1009 23:20:56.876411  2983 layer_factory.hpp:77] Creating layer data
# I1009 23:20:56.876430  2983 net.cpp:106] Creating Layer data
# I1009 23:20:56.876441  2983 net.cpp:411] data -> data
# I1009 23:20:56.876457  2983 net.cpp:411] data -> label
# I1009 23:20:56.876472  2983 hdf5_data_layer.cpp:79] Loading list of HDF5 filenames from: examples/hdf5_classification/data/test.txt
# I1009 23:20:56.876516  2983 hdf5_data_layer.cpp:93] Number of HDF5 files: 1
# I1009 23:20:56.877954  2983 net.cpp:150] Setting up data
# I1009 23:20:56.877998  2983 net.cpp:157] Top shape: 10 4 (40)
# I1009 23:20:56.878015  2983 net.cpp:157] Top shape: 10 (10)
# I1009 23:20:56.878026  2983 net.cpp:165] Memory required for data: 200
# I1009 23:20:56.878036  2983 layer_factory.hpp:77] Creating layer label_data_1_split
# I1009 23:20:56.878051  2983 net.cpp:106] Creating Layer label_data_1_split
# I1009 23:20:56.878062  2983 net.cpp:454] label_data_1_split <- label
# I1009 23:20:56.878075  2983 net.cpp:411] label_data_1_split -> label_data_1_split_0
# I1009 23:20:56.878092  2983 net.cpp:411] label_data_1_split -> label_data_1_split_1
# I1009 23:20:56.878113  2983 net.cpp:150] Setting up label_data_1_split
# I1009 23:20:56.878128  2983 net.cpp:157] Top shape: 10 (10)
# I1009 23:20:56.878139  2983 net.cpp:157] Top shape: 10 (10)
# I1009 23:20:56.878149  2983 net.cpp:165] Memory required for data: 280
# I1009 23:20:56.878159  2983 layer_factory.hpp:77] Creating layer ip1
# I1009 23:20:56.878173  2983 net.cpp:106] Creating Layer ip1
# I1009 23:20:56.878185  2983 net.cpp:454] ip1 <- data
# I1009 23:20:56.878197  2983 net.cpp:411] ip1 -> ip1
# I1009 23:20:56.878221  2983 net.cpp:150] Setting up ip1
# I1009 23:20:56.878235  2983 net.cpp:157] Top shape: 10 40 (400)
# I1009 23:20:56.878245  2983 net.cpp:165] Memory required for data: 1880
# I1009 23:20:56.878263  2983 layer_factory.hpp:77] Creating layer relu1
# I1009 23:20:56.878278  2983 net.cpp:106] Creating Layer relu1
# I1009 23:20:56.878288  2983 net.cpp:454] relu1 <- ip1
# I1009 23:20:56.878300  2983 net.cpp:397] relu1 -> ip1 (in-place)
# I1009 23:20:56.878445  2983 net.cpp:150] Setting up relu1
# I1009 23:20:56.878465  2983 net.cpp:157] Top shape: 10 40 (400)
# I1009 23:20:56.878476  2983 net.cpp:165] Memory required for data: 3480
# I1009 23:20:56.878486  2983 layer_factory.hpp:77] Creating layer ip2
# I1009 23:20:56.878501  2983 net.cpp:106] Creating Layer ip2
# I1009 23:20:56.878512  2983 net.cpp:454] ip2 <- ip1
# I1009 23:20:56.878525  2983 net.cpp:411] ip2 -> ip2
# I1009 23:20:56.878548  2983 net.cpp:150] Setting up ip2
# I1009 23:20:56.878562  2983 net.cpp:157] Top shape: 10 2 (20)
# I1009 23:20:56.878572  2983 net.cpp:165] Memory required for data: 3560
# I1009 23:20:56.878587  2983 layer_factory.hpp:77] Creating layer ip2_ip2_0_split
# I1009 23:20:56.878600  2983 net.cpp:106] Creating Layer ip2_ip2_0_split
# I1009 23:20:56.878612  2983 net.cpp:454] ip2_ip2_0_split <- ip2
# I1009 23:20:56.878623  2983 net.cpp:411] ip2_ip2_0_split -> ip2_ip2_0_split_0
# I1009 23:20:56.878638  2983 net.cpp:411] ip2_ip2_0_split -> ip2_ip2_0_split_1
# I1009 23:20:56.878653  2983 net.cpp:150] Setting up ip2_ip2_0_split
# I1009 23:20:56.878664  2983 net.cpp:157] Top shape: 10 2 (20)
# I1009 23:20:56.878675  2983 net.cpp:157] Top shape: 10 2 (20)
# I1009 23:20:56.878685  2983 net.cpp:165] Memory required for data: 3720
# I1009 23:20:56.878695  2983 layer_factory.hpp:77] Creating layer accuracy
# I1009 23:20:56.878706  2983 net.cpp:106] Creating Layer accuracy
# I1009 23:20:56.878717  2983 net.cpp:454] accuracy <- ip2_ip2_0_split_0
# I1009 23:20:56.878728  2983 net.cpp:454] accuracy <- label_data_1_split_0
# I1009 23:20:56.878741  2983 net.cpp:411] accuracy -> accuracy
# I1009 23:20:56.878756  2983 net.cpp:150] Setting up accuracy
# I1009 23:20:56.878768  2983 net.cpp:157] Top shape: (1)
# I1009 23:20:56.878778  2983 net.cpp:165] Memory required for data: 3724
# I1009 23:20:56.878788  2983 layer_factory.hpp:77] Creating layer loss
# I1009 23:20:56.878800  2983 net.cpp:106] Creating Layer loss
# I1009 23:20:56.878810  2983 net.cpp:454] loss <- ip2_ip2_0_split_1
# I1009 23:20:56.878821  2983 net.cpp:454] loss <- label_data_1_split_1
# I1009 23:20:56.878834  2983 net.cpp:411] loss -> loss
# I1009 23:20:56.878849  2983 layer_factory.hpp:77] Creating layer loss
# I1009 23:20:56.879086  2983 net.cpp:150] Setting up loss
# I1009 23:20:56.879107  2983 net.cpp:157] Top shape: (1)
# I1009 23:20:56.879118  2983 net.cpp:160]     with loss weight 1
# I1009 23:20:56.879148  2983 net.cpp:165] Memory required for data: 3728
# I1009 23:20:56.879163  2983 net.cpp:226] loss needs backward computation.
# I1009 23:20:56.879175  2983 net.cpp:228] accuracy does not need backward computation.
# I1009 23:20:56.879186  2983 net.cpp:226] ip2_ip2_0_split needs backward computation.
# I1009 23:20:56.879196  2983 net.cpp:226] ip2 needs backward computation.
# I1009 23:20:56.879206  2983 net.cpp:226] relu1 needs backward computation.
# I1009 23:20:56.879216  2983 net.cpp:226] ip1 needs backward computation.
# I1009 23:20:56.879226  2983 net.cpp:228] label_data_1_split does not need backward computation.
# I1009 23:20:56.879237  2983 net.cpp:228] data does not need backward computation.
# I1009 23:20:56.879246  2983 net.cpp:270] This network produces output accuracy
# I1009 23:20:56.879257  2983 net.cpp:270] This network produces output loss
# I1009 23:20:56.879272  2983 net.cpp:283] Network initialization done.
# I1009 23:20:56.879307  2983 solver.cpp:60] Solver scaffolding done.
# I1009 23:20:56.879339  2983 caffe.cpp:213] Starting Optimization
# I1009 23:20:56.879353  2983 solver.cpp:280] Solving
# I1009 23:20:56.879362  2983 solver.cpp:281] Learning Rate Policy: step
# I1009 23:20:56.879377  2983 solver.cpp:338] Iteration 0, Testing net (#0)
# I1009 23:20:56.883079  2983 solver.cpp:406]     Test net output #0: accuracy = 0.3488
# I1009 23:20:56.883116  2983 solver.cpp:406]     Test net output #1: loss = 0.987546 (* 1 = 0.987546 loss)
# I1009 23:20:56.883203  2983 solver.cpp:229] Iteration 0, loss = 0.771383
# I1009 23:20:56.883224  2983 solver.cpp:245]     Train net output #0: accuracy = 0.3
# I1009 23:20:56.883240  2983 solver.cpp:245]     Train net output #1: loss = 0.771383 (* 1 = 0.771383 loss)
# I1009 23:20:56.883260  2983 sgd_solver.cpp:106] Iteration 0, lr = 0.01
# I1009 23:20:56.907253  2983 solver.cpp:338] Iteration 1000, Testing net (#0)
# I1009 23:20:56.910821  2983 solver.cpp:406]     Test net output #0: accuracy = 0.8148
# I1009 23:20:56.910862  2983 solver.cpp:406]     Test net output #1: loss = 0.435183 (* 1 = 0.435183 loss)
# I1009 23:20:56.910907  2983 solver.cpp:229] Iteration 1000, loss = 0.365979
# I1009 23:20:56.910925  2983 solver.cpp:245]     Train net output #0: accuracy = 0.9
# I1009 23:20:56.910941  2983 solver.cpp:245]     Train net output #1: loss = 0.365979 (* 1 = 0.365979 loss)
# I1009 23:20:56.910954  2983 sgd_solver.cpp:106] Iteration 1000, lr = 0.01
# I1009 23:20:56.933786  2983 solver.cpp:338] Iteration 2000, Testing net (#0)
# I1009 23:20:56.937355  2983 solver.cpp:406]     Test net output #0: accuracy = 0.8148
# I1009 23:20:56.937392  2983 solver.cpp:406]     Test net output #1: loss = 0.416625 (* 1 = 0.416625 loss)
# I1009 23:20:56.937436  2983 solver.cpp:229] Iteration 2000, loss = 0.344574
# I1009 23:20:56.937454  2983 solver.cpp:245]     Train net output #0: accuracy = 0.9
# I1009 23:20:56.937471  2983 solver.cpp:245]     Train net output #1: loss = 0.344575 (* 1 = 0.344575 loss)
# I1009 23:20:56.937484  2983 sgd_solver.cpp:106] Iteration 2000, lr = 0.01
# I1009 23:20:56.961027  2983 solver.cpp:338] Iteration 3000, Testing net (#0)
# I1009 23:20:56.964615  2983 solver.cpp:406]     Test net output #0: accuracy = 0.8276
# I1009 23:20:56.964655  2983 solver.cpp:406]     Test net output #1: loss = 0.404545 (* 1 = 0.404545 loss)
# I1009 23:20:56.965162  2983 solver.cpp:229] Iteration 3000, loss = 0.362444
# I1009 23:20:56.965195  2983 solver.cpp:245]     Train net output #0: accuracy = 0.9
# I1009 23:20:56.965214  2983 solver.cpp:245]     Train net output #1: loss = 0.362444 (* 1 = 0.362444 loss)
# I1009 23:20:56.965227  2983 sgd_solver.cpp:106] Iteration 3000, lr = 0.01
# I1009 23:20:56.988592  2983 solver.cpp:338] Iteration 4000, Testing net (#0)
# I1009 23:20:56.992148  2983 solver.cpp:406]     Test net output #0: accuracy = 0.8188
# I1009 23:20:56.992177  2983 solver.cpp:406]     Test net output #1: loss = 0.414801 (* 1 = 0.414801 loss)
# I1009 23:20:56.992219  2983 solver.cpp:229] Iteration 4000, loss = 0.321895
# I1009 23:20:56.992238  2983 solver.cpp:245]     Train net output #0: accuracy = 0.9
# I1009 23:20:56.992254  2983 solver.cpp:245]     Train net output #1: loss = 0.321896 (* 1 = 0.321896 loss)
# I1009 23:20:56.992286  2983 sgd_solver.cpp:106] Iteration 4000, lr = 0.01
# I1009 23:20:57.015841  2983 solver.cpp:338] Iteration 5000, Testing net (#0)
# I1009 23:20:57.019430  2983 solver.cpp:406]     Test net output #0: accuracy = 0.822
# I1009 23:20:57.019466  2983 solver.cpp:406]     Test net output #1: loss = 0.404006 (* 1 = 0.404006 loss)
# I1009 23:20:57.019508  2983 solver.cpp:229] Iteration 5000, loss = 0.323443
# I1009 23:20:57.019527  2983 solver.cpp:245]     Train net output #0: accuracy = 0.9
# I1009 23:20:57.019544  2983 solver.cpp:245]     Train net output #1: loss = 0.323444 (* 1 = 0.323444 loss)
# I1009 23:20:57.019557  2983 sgd_solver.cpp:106] Iteration 5000, lr = 0.001
# I1009 23:20:57.042443  2983 solver.cpp:338] Iteration 6000, Testing net (#0)
# I1009 23:20:57.046116  2983 solver.cpp:406]     Test net output #0: accuracy = 0.8276
# I1009 23:20:57.046169  2983 solver.cpp:406]     Test net output #1: loss = 0.397662 (* 1 = 0.397662 loss)
# I1009 23:20:57.046710  2983 solver.cpp:229] Iteration 6000, loss = 0.364866
# I1009 23:20:57.046752  2983 solver.cpp:245]     Train net output #0: accuracy = 0.9
# I1009 23:20:57.046788  2983 solver.cpp:245]     Train net output #1: loss = 0.364867 (* 1 = 0.364867 loss)
# I1009 23:20:57.046808  2983 sgd_solver.cpp:106] Iteration 6000, lr = 0.001
# I1009 23:20:57.071101  2983 solver.cpp:338] Iteration 7000, Testing net (#0)
# I1009 23:20:57.074769  2983 solver.cpp:406]     Test net output #0: accuracy = 0.8252
# I1009 23:20:57.074820  2983 solver.cpp:406]     Test net output #1: loss = 0.395366 (* 1 = 0.395366 loss)
# I1009 23:20:57.074884  2983 solver.cpp:229] Iteration 7000, loss = 0.346395
# I1009 23:20:57.074906  2983 solver.cpp:245]     Train net output #0: accuracy = 0.9
# I1009 23:20:57.074923  2983 solver.cpp:245]     Train net output #1: loss = 0.346396 (* 1 = 0.346396 loss)
# I1009 23:20:57.074939  2983 sgd_solver.cpp:106] Iteration 7000, lr = 0.001
# I1009 23:20:57.097846  2983 solver.cpp:338] Iteration 8000, Testing net (#0)
# I1009 23:20:57.101526  2983 solver.cpp:406]     Test net output #0: accuracy = 0.8312
# I1009 23:20:57.101577  2983 solver.cpp:406]     Test net output #1: loss = 0.394204 (* 1 = 0.394204 loss)
# I1009 23:20:57.101640  2983 solver.cpp:229] Iteration 8000, loss = 0.294303
# I1009 23:20:57.101661  2983 solver.cpp:245]     Train net output #0: accuracy = 0.9
# I1009 23:20:57.101678  2983 solver.cpp:245]     Train net output #1: loss = 0.294303 (* 1 = 0.294303 loss)
# I1009 23:20:57.101691  2983 sgd_solver.cpp:106] Iteration 8000, lr = 0.001
# I1009 23:20:57.125892  2983 solver.cpp:338] Iteration 9000, Testing net (#0)
# I1009 23:20:57.129549  2983 solver.cpp:406]     Test net output #0: accuracy = 0.8264
# I1009 23:20:57.129600  2983 solver.cpp:406]     Test net output #1: loss = 0.396537 (* 1 = 0.396537 loss)
# I1009 23:20:57.130167  2983 solver.cpp:229] Iteration 9000, loss = 0.369432
# I1009 23:20:57.130210  2983 solver.cpp:245]     Train net output #0: accuracy = 0.9
# I1009 23:20:57.130247  2983 solver.cpp:245]     Train net output #1: loss = 0.369433 (* 1 = 0.369433 loss)
# I1009 23:20:57.130266  2983 sgd_solver.cpp:106] Iteration 9000, lr = 0.001
# I1009 23:20:57.153195  2983 solver.cpp:456] Snapshotting to binary proto file examples/hdf5_classification/data/train_iter_10000.caffemodel
# I1009 23:20:57.153491  2983 sgd_solver.cpp:273] Snapshotting solver state to binary proto file examples/hdf5_classification/data/train_iter_10000.solverstate
# I1009 23:20:57.153631  2983 solver.cpp:318] Iteration 10000, loss = 0.340542
# I1009 23:20:57.153661  2983 solver.cpp:338] Iteration 10000, Testing net (#0)
# I1009 23:20:57.157305  2983 solver.cpp:406]     Test net output #0: accuracy = 0.8252
# I1009 23:20:57.157348  2983 solver.cpp:406]     Test net output #1: loss = 0.394401 (* 1 = 0.394401 loss)
# I1009 23:20:57.157374  2983 solver.cpp:323] Optimization Done.
# I1009 23:20:57.157393  2983 caffe.cpp:216] Optimization Done.

# %%
# Clean up (comment this out if you want to examine the hdf5_classification/data directory).
shutil.rmtree(dirname)
